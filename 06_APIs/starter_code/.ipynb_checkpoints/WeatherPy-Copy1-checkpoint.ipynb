# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

from pprint import pprint

# Import API key
from api_keys import api_key
#print(api_key)

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# lats = np.random.uniform(low=-90.000, high=90.000, size=150)
# lngs = np.random.uniform(low=-180.000, high=180.000, size=150)

lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %%
#print(cities)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create an empty list to store the responses

base_url = "http://api.openweathermap.org/data/2.5/weather"

units = "imperial"

query_url = f'{base_url}?appid={api_key}&units={units}&q='

print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=f7108597839db7475a2c37928f58ffe3&units=imperial&q=

# %%
# create response lists
cityName = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lon = []
maxTemp = []
windSpeed = []

recordCount = 1
setCount = 1


# Make a request 
print(f"Beginning Data Retrieval")
print('-------------------------------------------')

for i, city in enumerate(cities):
    #print(i,city)
    
    if (i % 100 == 0 and i >= 100):
        recordCount = 1
        setCount = setCount + 1
    
    print(f'Processing Record {recordCount} of Set {setCount} | {city}')
    
    recordCount = recordCount + 1
    
    # Get one of the posts
   
    try:
         
        response = requests.get(query_url + city).json()
        #pprint(response)

        # Save post's JSON
        cityName.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        maxTemp.append(response['main']['temp_max'])
        windSpeed.append(response['wind']['speed'])
          
             
    except KeyError:
        print('City not found.  Skipping...')
        
        #print('City not found.  Skipping city name...'+ city)
        
        #print('--------------------------------------------')
# Out:
# Beginning Data Retrieval
# -------------------------------------------
# Processing Record 1 of Set 1 | illoqqortoormiut
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | tumannyy
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 5 of Set 1 | maragogi
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | kiruna
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | chokurdakh
# Processing Record 11 of Set 1 | srednekolymsk
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | lethem
# Processing Record 14 of Set 1 | iranshahr
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | ust-tsilma
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | katsuura
# Processing Record 20 of Set 1 | arraial do cabo
# Processing Record 21 of Set 1 | karratha
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | mount gambier
# Processing Record 25 of Set 1 | lagoa
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | oktyabrskiy
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | marrakesh
# Processing Record 30 of Set 1 | bambous virieux
# Processing Record 31 of Set 1 | paamiut
# Processing Record 32 of Set 1 | lompoc
# Processing Record 33 of Set 1 | saint-philippe
# Processing Record 34 of Set 1 | dongsheng
# Processing Record 35 of Set 1 | esperance
# Processing Record 36 of Set 1 | attawapiskat
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | cabo san lucas
# Processing Record 39 of Set 1 | nabire
# Processing Record 40 of Set 1 | gat
# Processing Record 41 of Set 1 | saint-augustin
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | daru
# Processing Record 44 of Set 1 | cidreira
# Processing Record 45 of Set 1 | tsihombe
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 46 of Set 1 | kodiak
# Processing Record 47 of Set 1 | westport
# Processing Record 48 of Set 1 | bethel
# Processing Record 49 of Set 1 | grand river south east
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 51 of Set 1 | nizhneyansk
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 52 of Set 1 | otane
# Processing Record 53 of Set 1 | mahebourg
# Processing Record 54 of Set 1 | port-gentil
# Processing Record 55 of Set 1 | tual
# Processing Record 56 of Set 1 | upernavik
# Processing Record 57 of Set 1 | saint-denis
# Processing Record 58 of Set 1 | taolanaro
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 59 of Set 1 | jonesboro
# Processing Record 60 of Set 1 | beyneu
# Processing Record 61 of Set 1 | nikolskoye
# Processing Record 62 of Set 1 | tailai
# Processing Record 63 of Set 1 | tasiilaq
# Processing Record 64 of Set 1 | bengkulu
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 65 of Set 1 | along
# Processing Record 66 of Set 1 | mogocha
# Processing Record 67 of Set 1 | margherita
# Processing Record 68 of Set 1 | abilene
# Processing Record 69 of Set 1 | bredasdorp
# Processing Record 70 of Set 1 | victoria
# Processing Record 71 of Set 1 | ushuaia
# Processing Record 72 of Set 1 | tessalit
# Processing Record 73 of Set 1 | santo antonio de jesus
# Processing Record 74 of Set 1 | saint anthony
# Processing Record 75 of Set 1 | akureyri
# Processing Record 76 of Set 1 | khatanga
# Processing Record 77 of Set 1 | tuktoyaktuk
# Processing Record 78 of Set 1 | katha
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 79 of Set 1 | hithadhoo
# Processing Record 80 of Set 1 | hofn
# Processing Record 81 of Set 1 | butaritari
# Processing Record 82 of Set 1 | ostrovnoy
# Processing Record 83 of Set 1 | narsaq
# Processing Record 84 of Set 1 | marinette
# Processing Record 85 of Set 1 | carnarvon
# Processing Record 86 of Set 1 | saint-joseph
# Processing Record 87 of Set 1 | urumqi
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 88 of Set 1 | tiksi
# Processing Record 89 of Set 1 | shingu
# Processing Record 90 of Set 1 | port alfred
# Processing Record 91 of Set 1 | luderitz
# Processing Record 92 of Set 1 | plouzane
# Processing Record 93 of Set 1 | airai
# Processing Record 94 of Set 1 | thompson
# Processing Record 95 of Set 1 | aklavik
# Processing Record 96 of Set 1 | high level
# Processing Record 97 of Set 1 | portland
# Processing Record 98 of Set 1 | codrington
# Processing Record 99 of Set 1 | birjand
# Processing Record 100 of Set 1 | buluang
# Processing Record 1 of Set 2 | toora-khem
# Processing Record 2 of Set 2 | shirochanka
# Processing Record 3 of Set 2 | koygorodok
# Processing Record 4 of Set 2 | ribeira grande
# Processing Record 5 of Set 2 | yerbogachen
# Processing Record 6 of Set 2 | san patricio
# Processing Record 7 of Set 2 | claremorris
# Processing Record 8 of Set 2 | lubao
# Processing Record 9 of Set 2 | vardo
# Processing Record 10 of Set 2 | saint-francois
# Processing Record 11 of Set 2 | rongcheng
# Processing Record 12 of Set 2 | cherskiy
# Processing Record 13 of Set 2 | worland
# Processing Record 14 of Set 2 | yeniseysk
# Processing Record 15 of Set 2 | mar del plata
# Processing Record 16 of Set 2 | antofagasta
# Processing Record 17 of Set 2 | qaanaaq
# Processing Record 18 of Set 2 | te anau
# Processing Record 19 of Set 2 | vaini
# Processing Record 20 of Set 2 | saleaula
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 21 of Set 2 | saint george
# Processing Record 22 of Set 2 | olafsvik
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 23 of Set 2 | ponta do sol
# Processing Record 24 of Set 2 | jamestown
# Processing Record 25 of Set 2 | pacific grove
# Processing Record 26 of Set 2 | elizabeth city
# Processing Record 27 of Set 2 | praya
# Processing Record 28 of Set 2 | qena
# Processing Record 29 of Set 2 | sokolka
# Processing Record 30 of Set 2 | constitucion
# Processing Record 31 of Set 2 | nanortalik
# Processing Record 32 of Set 2 | sentyabrskiy
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 33 of Set 2 | vanimo
# Processing Record 34 of Set 2 | saint-pierre
# Processing Record 35 of Set 2 | benguela
# Processing Record 36 of Set 2 | bintulu
# Processing Record 37 of Set 2 | kargil
# Processing Record 38 of Set 2 | parakai
# Processing Record 39 of Set 2 | shizunai
# Processing Record 40 of Set 2 | amderma
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 41 of Set 2 | severo-kurilsk
# Processing Record 42 of Set 2 | georgetown
# Processing Record 43 of Set 2 | dharchula
# Processing Record 44 of Set 2 | samusu
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 45 of Set 2 | port elizabeth
# Processing Record 46 of Set 2 | traverse city
# Processing Record 47 of Set 2 | san policarpo
# Processing Record 48 of Set 2 | phalombe
# Processing Record 49 of Set 2 | pastavy
# Processing Record 50 of Set 2 | yar-sale
# Processing Record 51 of Set 2 | shimoda
# Processing Record 52 of Set 2 | nome
# Processing Record 53 of Set 2 | bluefields
# Processing Record 54 of Set 2 | adre
# Processing Record 55 of Set 2 | provideniya
# Processing Record 56 of Set 2 | iracoubo
# Processing Record 57 of Set 2 | nchelenge
# Processing Record 58 of Set 2 | straumen
# Processing Record 59 of Set 2 | tabou
# Processing Record 60 of Set 2 | shahabad
# Processing Record 61 of Set 2 | dentsville
# Processing Record 62 of Set 2 | faanui
# Processing Record 63 of Set 2 | wajir
# Processing Record 64 of Set 2 | rocha
# Processing Record 65 of Set 2 | berbera
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 66 of Set 2 | kamenskoye
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 67 of Set 2 | komsomolskiy
# Processing Record 68 of Set 2 | djibo
# Processing Record 69 of Set 2 | juquia
# Processing Record 70 of Set 2 | irtyshskiy
# Processing Record 71 of Set 2 | yellowknife
# Processing Record 72 of Set 2 | leningradskiy
# Processing Record 73 of Set 2 | tadine
# Processing Record 74 of Set 2 | iqaluit
# Processing Record 75 of Set 2 | takoradi
# Processing Record 76 of Set 2 | rungata
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 77 of Set 2 | tautira
# Processing Record 78 of Set 2 | umzimvubu
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 79 of Set 2 | juneau
# Processing Record 80 of Set 2 | evensk
# Processing Record 81 of Set 2 | bharatpur
# Processing Record 82 of Set 2 | kaitangata
# Processing Record 83 of Set 2 | northam
# Processing Record 84 of Set 2 | pinega
# Processing Record 85 of Set 2 | murgab
# Processing Record 86 of Set 2 | fortuna
# Processing Record 87 of Set 2 | sistranda
# Processing Record 88 of Set 2 | honningsvag
# Processing Record 89 of Set 2 | bocas del toro
# Processing Record 90 of Set 2 | waingapu
# Processing Record 91 of Set 2 | ormara
# Processing Record 92 of Set 2 | malinovoye ozero
# Processing Record 93 of Set 2 | nyurba
# Processing Record 94 of Set 2 | mirebalais
# Processing Record 95 of Set 2 | lebu
# Processing Record 96 of Set 2 | san jose
# Processing Record 97 of Set 2 | tura
# Processing Record 98 of Set 2 | seminole
# Processing Record 99 of Set 2 | colares
# Processing Record 100 of Set 2 | klaksvik
# Processing Record 1 of Set 3 | belaya gora
# Processing Record 2 of Set 3 | xuddur
# Processing Record 3 of Set 3 | port lincoln
# Processing Record 4 of Set 3 | jumla
# Processing Record 5 of Set 3 | clarence town
# Processing Record 6 of Set 3 | bathsheba
# Processing Record 7 of Set 3 | puerto carreno
# Processing Record 8 of Set 3 | saldanha
# Processing Record 9 of Set 3 | samana
# Processing Record 10 of Set 3 | husavik
# Processing Record 11 of Set 3 | khonuu
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 12 of Set 3 | kenai
# Processing Record 13 of Set 3 | mys shmidta
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 14 of Set 3 | praia
# Processing Record 15 of Set 3 | chimbote
# Processing Record 16 of Set 3 | newala
# Processing Record 17 of Set 3 | salalah
# Processing Record 18 of Set 3 | avarua
# Processing Record 19 of Set 3 | hamilton
# Processing Record 20 of Set 3 | adrar
# Processing Record 21 of Set 3 | ternate
# Processing Record 22 of Set 3 | asasa
# Processing Record 23 of Set 3 | houma
# Processing Record 24 of Set 3 | clyde river
# Processing Record 25 of Set 3 | buraydah
# Processing Record 26 of Set 3 | belmonte
# Processing Record 27 of Set 3 | sangar
# Processing Record 28 of Set 3 | dicabisagan
# Processing Record 29 of Set 3 | ahar
# Processing Record 30 of Set 3 | barentsburg
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 31 of Set 3 | alice springs
# Processing Record 32 of Set 3 | kaniama
# Processing Record 33 of Set 3 | hasaki
# Processing Record 34 of Set 3 | jawhar
# Processing Record 35 of Set 3 | kristiansund
# Processing Record 36 of Set 3 | didwana
# Processing Record 37 of Set 3 | candido de abreu
# Processing Record 38 of Set 3 | yeghegnavan
# Processing Record 39 of Set 3 | castro
# Processing Record 40 of Set 3 | kavaratti
# Processing Record 41 of Set 3 | palabuhanratu
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 42 of Set 3 | mayo
# Processing Record 43 of Set 3 | ancud
# Processing Record 44 of Set 3 | shaunavon
# Processing Record 45 of Set 3 | roald
# Processing Record 46 of Set 3 | sinnamary
# Processing Record 47 of Set 3 | mahroni
# Processing Record 48 of Set 3 | hilo
# Processing Record 49 of Set 3 | chardara
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 50 of Set 3 | pevek
# Processing Record 51 of Set 3 | lensk
# Processing Record 52 of Set 3 | dingle
# Processing Record 53 of Set 3 | conceicao do araguaia
# Processing Record 54 of Set 3 | vallenar
# Processing Record 55 of Set 3 | vila franca do campo
# Processing Record 56 of Set 3 | boddam
# Processing Record 57 of Set 3 | axim
# Processing Record 58 of Set 3 | imbituba
# Processing Record 59 of Set 3 | pisco
# Processing Record 60 of Set 3 | ambilobe
# Processing Record 61 of Set 3 | muros
# Processing Record 62 of Set 3 | maloy
# Processing Record 63 of Set 3 | burica
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 64 of Set 3 | neiafu
# Processing Record 65 of Set 3 | ilulissat
# Processing Record 66 of Set 3 | malanje
# Processing Record 67 of Set 3 | snejbjerg
# Processing Record 68 of Set 3 | monroe
# Processing Record 69 of Set 3 | mukhen
# Processing Record 70 of Set 3 | ikongo
# Processing Record 71 of Set 3 | ondjiva
# Processing Record 72 of Set 3 | los llanos de aridane
# Processing Record 73 of Set 3 | gigmoto
# Processing Record 74 of Set 3 | touros
# Processing Record 75 of Set 3 | bambui
# Processing Record 76 of Set 3 | saint augustine
# Processing Record 77 of Set 3 | chiali
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 78 of Set 3 | souillac
# Processing Record 79 of Set 3 | chuy
# Processing Record 80 of Set 3 | tamiahua
# Processing Record 81 of Set 3 | mananjary
# Processing Record 82 of Set 3 | rosarito
# Processing Record 83 of Set 3 | big bend
# Processing Record 84 of Set 3 | haines junction
# Processing Record 85 of Set 3 | benemerito de las americas
# Processing Record 86 of Set 3 | karakol
# Processing Record 87 of Set 3 | dwarka
# Processing Record 88 of Set 3 | boguchany
# Processing Record 89 of Set 3 | yanliang
# Processing Record 90 of Set 3 | kruisfontein
# Processing Record 91 of Set 3 | vaitupu
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 92 of Set 3 | catuday
# Processing Record 93 of Set 3 | bubaque
# Processing Record 94 of Set 3 | corrente
# Processing Record 95 of Set 3 | cumaribo
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 96 of Set 3 | segezha
# Processing Record 97 of Set 3 | taltal
# Processing Record 98 of Set 3 | glendive
# Processing Record 99 of Set 3 | verkhnevilyuysk
# Processing Record 100 of Set 3 | chastyye
# Processing Record 1 of Set 4 | hobyo
# Processing Record 2 of Set 4 | pangnirtung
# Processing Record 3 of Set 4 | buariki
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 4 of Set 4 | chapais
# Processing Record 5 of Set 4 | aniva
# Processing Record 6 of Set 4 | balagansk
# Processing Record 7 of Set 4 | kungurtug
# Processing Record 8 of Set 4 | baherden
# Processing Record 9 of Set 4 | bandarbeyla
# Processing Record 10 of Set 4 | broome
# Processing Record 11 of Set 4 | henties bay
# Processing Record 12 of Set 4 | lasa
# Processing Record 13 of Set 4 | gilgit
# Processing Record 14 of Set 4 | jicayan
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 15 of Set 4 | panjab
# Processing Record 16 of Set 4 | maniitsoq
# Processing Record 17 of Set 4 | panguna
# Processing Record 18 of Set 4 | dzhusaly
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 19 of Set 4 | yumen
# Processing Record 20 of Set 4 | tiarei
# Processing Record 21 of Set 4 | deneysville
# Processing Record 22 of Set 4 | tromso
# Processing Record 23 of Set 4 | coihaique
# Processing Record 24 of Set 4 | mazagao
# Processing Record 25 of Set 4 | nyrob
# Processing Record 26 of Set 4 | nyagan
# Processing Record 27 of Set 4 | agadez
# Processing Record 28 of Set 4 | champerico
# Processing Record 29 of Set 4 | mitu
# Processing Record 30 of Set 4 | san cristobal
# Processing Record 31 of Set 4 | valparaiso
# Processing Record 32 of Set 4 | lolua
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 33 of Set 4 | mae hong son
# Processing Record 34 of Set 4 | acapulco
# Processing Record 35 of Set 4 | sept-iles
# Processing Record 36 of Set 4 | lorengau
# Processing Record 37 of Set 4 | brae
# Processing Record 38 of Set 4 | maningrida
# Processing Record 39 of Set 4 | jamame
# Processing Record 40 of Set 4 | odesskoye
# Processing Record 41 of Set 4 | huarmey
# Processing Record 42 of Set 4 | chunskiy
# Processing Record 43 of Set 4 | prince rupert
# Processing Record 44 of Set 4 | ahipara
# Processing Record 45 of Set 4 | sabang
# Processing Record 46 of Set 4 | chipinge
# Processing Record 47 of Set 4 | shambu
# Processing Record 48 of Set 4 | coahuayana
# Processing Record 49 of Set 4 | kidodi
# Processing Record 50 of Set 4 | ilanskiy
# Processing Record 51 of Set 4 | lima
# Processing Record 52 of Set 4 | kahta
# Processing Record 53 of Set 4 | makakilo city
# Processing Record 54 of Set 4 | beringovskiy
# Processing Record 55 of Set 4 | akyab
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 56 of Set 4 | amapa
# Processing Record 57 of Set 4 | aswan
# Processing Record 58 of Set 4 | kudahuvadhoo
# Processing Record 59 of Set 4 | verkhoyansk
# Processing Record 60 of Set 4 | antissa
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 61 of Set 4 | goderich
# Processing Record 62 of Set 4 | nantucket
# Processing Record 63 of Set 4 | mossoro
# Processing Record 64 of Set 4 | geraldton
# Processing Record 65 of Set 4 | sitka
# Processing Record 66 of Set 4 | tateyama
# Processing Record 67 of Set 4 | kiama
# Processing Record 68 of Set 4 | waipawa
# Processing Record 69 of Set 4 | rantepao
# Processing Record 70 of Set 4 | poya
# Processing Record 71 of Set 4 | kalevala
# Processing Record 72 of Set 4 | mangrol
# Processing Record 73 of Set 4 | umm lajj
# Processing Record 74 of Set 4 | razole
# Processing Record 75 of Set 4 | berlevag
# Processing Record 76 of Set 4 | khoni
# Processing Record 77 of Set 4 | kavieng
# Processing Record 78 of Set 4 | poum
# Processing Record 79 of Set 4 | esqueda
# Processing Record 80 of Set 4 | naftah
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 81 of Set 4 | collie
# Processing Record 82 of Set 4 | iskateley
# Processing Record 83 of Set 4 | phalodi
# Processing Record 84 of Set 4 | lisakovsk
# Processing Record 85 of Set 4 | ceres
# Processing Record 86 of Set 4 | hambantota
# Processing Record 87 of Set 4 | palora
# Processing Record 88 of Set 4 | ghanzi
# Processing Record 89 of Set 4 | lobva
# Processing Record 90 of Set 4 | talnakh
# Processing Record 91 of Set 4 | morgan city
# Processing Record 92 of Set 4 | puerto del rosario
# Processing Record 93 of Set 4 | torbay
# Processing Record 94 of Set 4 | mogadishu
# Processing Record 95 of Set 4 | mehamn
# Processing Record 96 of Set 4 | saskylakh
# Processing Record 97 of Set 4 | parlakimidi
# Processing Record 98 of Set 4 | camacha
# Processing Record 99 of Set 4 | bushehr
# Processing Record 100 of Set 4 | horki
# Processing Record 1 of Set 5 | college
# Processing Record 2 of Set 5 | mosquera
# Processing Record 3 of Set 5 | tamandare
# Processing Record 4 of Set 5 | ucluelet
# Processing Record 5 of Set 5 | milkovo
# Processing Record 6 of Set 5 | roman
# Processing Record 7 of Set 5 | emirdag
# Processing Record 8 of Set 5 | tuatapere
# Processing Record 9 of Set 5 | zyryanka
# Processing Record 10 of Set 5 | grindavik
# Processing Record 11 of Set 5 | teknaf
# Processing Record 12 of Set 5 | rio gallegos
# Processing Record 13 of Set 5 | weligama
# Processing Record 14 of Set 5 | xiaoyi
# Processing Record 15 of Set 5 | san ramon
# Processing Record 16 of Set 5 | durango
# Processing Record 17 of Set 5 | meyungs
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 18 of Set 5 | esfahan
# Processing Record 19 of Set 5 | cabedelo
# Processing Record 20 of Set 5 | hami
# Processing Record 21 of Set 5 | at-bashi
# Processing Record 22 of Set 5 | yuli
# Processing Record 23 of Set 5 | sao filipe
# Processing Record 24 of Set 5 | san rafael
# Processing Record 25 of Set 5 | krapivinskiy
# Processing Record 26 of Set 5 | svetlaya
# Processing Record 27 of Set 5 | gamba
# Processing Record 28 of Set 5 | shache
# Processing Record 29 of Set 5 | santa rosalia
# Processing Record 30 of Set 5 | chipata
# Processing Record 31 of Set 5 | cockburn town
# Processing Record 32 of Set 5 | louisbourg
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 33 of Set 5 | havre-saint-pierre
# Processing Record 34 of Set 5 | primorsk
# Processing Record 35 of Set 5 | bridlington
# Processing Record 36 of Set 5 | mount isa
# Processing Record 37 of Set 5 | inhambane
# Processing Record 38 of Set 5 | bahia blanca
# Processing Record 39 of Set 5 | valkeakoski
# Processing Record 40 of Set 5 | anstruther
# Processing Record 41 of Set 5 | innisfail
# Processing Record 42 of Set 5 | zaysan
# Processing Record 43 of Set 5 | bud
# Processing Record 44 of Set 5 | namtsy
# Processing Record 45 of Set 5 | puerto madero
# Processing Record 46 of Set 5 | selma
# Processing Record 47 of Set 5 | sotouboua
# Processing Record 48 of Set 5 | fethiye
# Processing Record 49 of Set 5 | vao
# Processing Record 50 of Set 5 | nowy dwor gdanski
# Processing Record 51 of Set 5 | walvis bay
# Processing Record 52 of Set 5 | oriximina
# Processing Record 53 of Set 5 | wattegama
# Processing Record 54 of Set 5 | egvekinot
# Processing Record 55 of Set 5 | alofi
# Processing Record 56 of Set 5 | angoche
# Processing Record 57 of Set 5 | havoysund
# Processing Record 58 of Set 5 | abu samrah
# Processing Record 59 of Set 5 | hokitika
# Processing Record 60 of Set 5 | maykain
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 61 of Set 5 | moranbah
# Processing Record 62 of Set 5 | dakoro
# Processing Record 63 of Set 5 | lhokseumawe
# Processing Record 64 of Set 5 | conde
# Processing Record 65 of Set 5 | sorong
# Processing Record 66 of Set 5 | sweetwater
# Processing Record 67 of Set 5 | vostok
# Processing Record 68 of Set 5 | dossor
# Processing Record 69 of Set 5 | petatlan
# Processing Record 70 of Set 5 | sola
# Processing Record 71 of Set 5 | warqla
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 72 of Set 5 | piacabucu
# Processing Record 73 of Set 5 | sorvag
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 74 of Set 5 | krasnoselkup
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 75 of Set 5 | puerto ayacucho
# Processing Record 76 of Set 5 | beira
# Processing Record 77 of Set 5 | plettenberg bay
# Processing Record 78 of Set 5 | kyabe
# Processing Record 79 of Set 5 | chengdu
# Processing Record 80 of Set 5 | tarudant
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 81 of Set 5 | ulladulla
# Processing Record 82 of Set 5 | rio grande
# Processing Record 83 of Set 5 | olhao
# Processing Record 84 of Set 5 | durazno
# Processing Record 85 of Set 5 | flinders
# Processing Record 86 of Set 5 | gorontalo
# Processing Record 87 of Set 5 | santo antonio do taua
# Processing Record 88 of Set 5 | belushya guba
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 89 of Set 5 | longyearbyen
# Processing Record 90 of Set 5 | lazaro cardenas
# Processing Record 91 of Set 5 | noormarkku
# Processing Record 92 of Set 5 | doha
# Processing Record 93 of Set 5 | palmer
# Processing Record 94 of Set 5 | caravelas
# Processing Record 95 of Set 5 | erzin
# Processing Record 96 of Set 5 | kumluca
# Processing Record 97 of Set 5 | baykit
# Processing Record 98 of Set 5 | norman wells
# Processing Record 99 of Set 5 | nemuro
# Processing Record 100 of Set 5 | morant bay
# Processing Record 1 of Set 6 | alpena
# Processing Record 2 of Set 6 | elat
# Processing Record 3 of Set 6 | aksarka
# Processing Record 4 of Set 6 | surami
# Processing Record 5 of Set 6 | vitre
# Processing Record 6 of Set 6 | nouadhibou
# Processing Record 7 of Set 6 | padang
# Processing Record 8 of Set 6 | kamaishi
# Processing Record 9 of Set 6 | pochutla
# Processing Record 10 of Set 6 | takhatgarh
# Processing Record 11 of Set 6 | gouyave
# Processing Record 12 of Set 6 | arcachon
# Processing Record 13 of Set 6 | canavieiras
# Processing Record 14 of Set 6 | maldonado
# Processing Record 15 of Set 6 | auki
# Processing Record 16 of Set 6 | san quintin
# Processing Record 17 of Set 6 | two rivers
# Processing Record 18 of Set 6 | zaozerne
# Processing Record 19 of Set 6 | baruun-urt
# Processing Record 20 of Set 6 | vila velha
# Processing Record 21 of Set 6 | vaitape
# Processing Record 22 of Set 6 | gazanjyk
# Processing Record 23 of Set 6 | taos
# Processing Record 24 of Set 6 | feira grande
# Processing Record 25 of Set 6 | ixtapa
# Processing Record 26 of Set 6 | tir pol
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 27 of Set 6 | zhanaozen
# Processing Record 28 of Set 6 | solnechnyy
# Processing Record 29 of Set 6 | karaul
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 30 of Set 6 | talikota
# Processing Record 31 of Set 6 | carinhanha
# Processing Record 32 of Set 6 | barra
# Processing Record 33 of Set 6 | tezu
# Processing Record 34 of Set 6 | chengmai
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 35 of Set 6 | rundu
# Processing Record 36 of Set 6 | gisborne
# Processing Record 37 of Set 6 | leo
# Processing Record 38 of Set 6 | monticello
# Processing Record 39 of Set 6 | sao miguel do araguaia
# Processing Record 40 of Set 6 | quelimane
# Processing Record 41 of Set 6 | borogontsy
# Processing Record 42 of Set 6 | cefalu
# Processing Record 43 of Set 6 | parati
# Processing Record 44 of Set 6 | finnsnes
# Processing Record 45 of Set 6 | rawson
# Processing Record 46 of Set 6 | yulara
# Processing Record 47 of Set 6 | vysokogornyy
# Processing Record 48 of Set 6 | meulaboh
# Processing Record 49 of Set 6 | kuusamo
# Processing Record 50 of Set 6 | chubbuck
# Processing Record 51 of Set 6 | faya
# Processing Record 52 of Set 6 | horsham
# Processing Record 53 of Set 6 | mantamados
# Processing Record 54 of Set 6 | kovernino
# Processing Record 55 of Set 6 | tinskoy
# Processing Record 56 of Set 6 | mokolo
# Processing Record 57 of Set 6 | tongren
# Processing Record 58 of Set 6 | anchorage
# Processing Record 59 of Set 6 | kirksville
# Processing Record 60 of Set 6 | tay ninh
# Processing Record 61 of Set 6 | barao de melgaco
# Processing Record 62 of Set 6 | shuyskoye
# Processing Record 63 of Set 6 | tawang
# Processing Record 64 of Set 6 | eresos
# Processing Record 65 of Set 6 | tanout
# Processing Record 66 of Set 6 | bonthe
# Processing Record 67 of Set 6 | kaili
# Processing Record 68 of Set 6 | xining
# Processing Record 69 of Set 6 | jiwani
# Processing Record 70 of Set 6 | troitsko-pechorsk
# Processing Record 71 of Set 6 | mozhaysk
# Processing Record 72 of Set 6 | charters towers
# Processing Record 73 of Set 6 | marcona
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 74 of Set 6 | newton
# Processing Record 75 of Set 6 | kaya
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 76 of Set 6 | namibe
# Processing Record 77 of Set 6 | asfi
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 78 of Set 6 | aporawan
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 79 of Set 6 | sao joao da barra
# Processing Record 80 of Set 6 | tecoanapa
# Processing Record 81 of Set 6 | santa cruz cabralia
# Processing Record 82 of Set 6 | barmer
# Processing Record 83 of Set 6 | babanusah
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 84 of Set 6 | natal
# Processing Record 85 of Set 6 | dekoa
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 86 of Set 6 | waverly
# Processing Record 87 of Set 6 | lancaster
# Processing Record 88 of Set 6 | havelock
# Processing Record 89 of Set 6 | tahoua
# Processing Record 90 of Set 6 | praia da vitoria
# Processing Record 91 of Set 6 | iquique
# Processing Record 92 of Set 6 | skoghall
# Processing Record 93 of Set 6 | isangel
# Processing Record 94 of Set 6 | rach gia
# Processing Record 95 of Set 6 | lavrentiya
# Processing Record 96 of Set 6 | mizdah
# Processing Record 97 of Set 6 | coffs harbour
# Processing Record 98 of Set 6 | asau
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 99 of Set 6 | ankazoabo
# Processing Record 100 of Set 6 | high rock
# Processing Record 1 of Set 7 | jalu
# Processing Record 2 of Set 7 | saint-georges
# Processing Record 3 of Set 7 | sambava
# Processing Record 4 of Set 7 | inhuma
# Processing Record 5 of Set 7 | cayenne
# Processing Record 6 of Set 7 | inta
# Processing Record 7 of Set 7 | salamanca
# Processing Record 8 of Set 7 | goundi
# Processing Record 9 of Set 7 | ovalle
# Processing Record 10 of Set 7 | trento
# Processing Record 11 of Set 7 | qasigiannguit
# Processing Record 12 of Set 7 | mumford
# Processing Record 13 of Set 7 | karauzyak
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 14 of Set 7 | sakakah
# City not found.  Skipping...
# --------------------------------------------
# Processing Record 15 of Set 7 | ariquemes
# Processing Record 16 of Set 7 | salto del guaira

# %%
print(len(cityName))
print(len(cloudiness))
print(len(country))
print(len(date))
print(len(humidity))
print(len(lat))
print(len(lon))
print(len(maxTemp))
print(len(windSpeed))
# #print(windSpeed)
# Out:
# 561
# 561
# 561
# 561
# 561
# 561
# 561
# 561
# 561

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    'City': cityName,
    'Cloudiness': cloudiness,
    'Country': country,
    'Date': date,
    'Humidity': humidity,
    'Latitude': lat,
    'Longitude': lon,
    'Max Temp': maxTemp,
    'Wind Speed': windSpeed
       }

#print (weather_dict)
weatherData = pd.DataFrame(weather_dict)
weatherData.head()
# Out:
#           City  Cloudiness Country        Date  Humidity  Latitude  Longitude  \
# 0    Cape Town           0      ZA  1554494530        59    -33.93      18.42
# 1       Albany          90      US  1554494419        80     42.65     -73.75
# 2     Maragogi          44      BR  1554494349        82     -9.01     -35.22
# 3  East London          92      ZA  1554494408       100    -33.02      27.91
# 4        Kapaa          40      US  1554494520        65     22.08    -159.32
#
#    Max Temp  Wind Speed
# 0     63.00       18.34
# 1     41.00       10.29
# 2     81.19        7.43
# 3     67.51        7.76
# 4     77.00        1.05

# %%
weatherData.tail()
weatherData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 9 columns):
# City          561 non-null object
# Cloudiness    561 non-null int64
# Country       561 non-null object
# Date          561 non-null int64
# Humidity      561 non-null int64
# Latitude      561 non-null float64
# Longitude     561 non-null float64
# Max Temp      561 non-null float64
# Wind Speed    561 non-null float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 39.5+ KB

# %%
# export to csv file

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
